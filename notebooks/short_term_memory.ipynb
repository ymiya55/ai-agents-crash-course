# %% [markdown]
# # Short Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# Bananas are healthier than lollipops.
# 1) Bananas: 7/10 - Natural fruit; contains fiber, potassium, and vitamins; moderate calories.
# 2) Lollipop: 2/10 - High added sugar, no nutrients; empty calories.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# I’m missing the other foods to compare with apples. Which foods should I include? (e.g., bananas, oranges, cookies, etc.)
#
# If you want a quick example with common fruits, I can do: apples vs bananas vs oranges.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# 1) Banana: 8/10 - Natural sugars plus fiber, potassium, and vitamins; supports energy and nutrition.
# 2) Lollipop: 2/10 - Pure sugar with little to no nutrients; contributes to cavities and energy crash.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# 1) Banana: 8/10 - Natural sugars, fiber, potassium, vitamins; supports energy and nutrition.
# 2) Apple: 7/10 - Fiber, vitamin C, antioxidants; lower sugar and calories than a banana per typical serving.
# 3) Lollipop: 2/10 - Pure sugar with little to no nutrients; contributes to cavities and energy crash.
